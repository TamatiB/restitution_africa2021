# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import ast

# %%
import CleanTweets as ct
# Out:
# [nltk_data] Downloading package stopwords to /Users/Lono/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/Lono/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from nltk import bigrams
import itertools
import collections

# %%
african_names = pd.read_csv("africa_names.csv", names = ["names", "nan"])
fix_list = african_names["names"].to_list()

# %%
def get_wordcloud(df, text_col, title):# Generate a word cloud image
    wordcloud = WordCloud(background_color="white", width=1500, height=800).generate(' '.join(df[text_col]))

    # Display the generated image:

    plt.figure(figsize=(18,10))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.savefig('../artefacts/' + title +'.eps', format='eps')

# %%
def draw_network(df, text_col, max_similarity, name):
    
    cv = CountVectorizer(ngram_range=(1,1), stop_words = 'english') # You can define your own parameters
    X = cv.fit_transform(df[text_col])
    Xc = (X.T * X) # Cosine similarity of words

    names = cv.get_feature_names() # This are the entity names (i.e. keywords)
    df_co = pd.DataFrame(data = Xc.toarray(), columns = names, index = names)

    a = df_co.stack().reset_index()
    a.columns = ['source', 'target','value']
    a_filtered=a.loc[ (a['value'] > max_similarity) & (a['source'] != a['target']) ]


    # Build your graph
    plt.figure(figsize=(20,10))
    G=nx.from_pandas_edgelist(a_filtered, 'source', 'target')

    # Plot the network:
    # pos = graphviz_layout(G)
    nx.draw(G, with_labels=True, node_color='orange', node_size=50, edge_color='green', linewidths=2, font_size=15)
    plt.savefig('../artefacts/' + name +'.eps', format='eps')

# %%
# https://www.earthdatascience.org/courses/use-data-open-source-python/intro-to-apis/calculate-tweet-word-bigrams/
def draw_cooccur_network(df, top_n_bigrams, col, title):
    terms_bigram = [list(bigrams(doc.split())) for doc in df[col]]
    bigramsls = list(itertools.chain(*terms_bigram))
    bigram_counts = collections.Counter(bigramsls)
    bigram_df = pd.DataFrame(bigram_counts.most_common(top_n_bigrams),
                                 columns=['bigram', 'count'])
    d = bigram_df.set_index('bigram').T.to_dict('records')

    # Create network plot 
    G = nx.Graph()

    # Create connections between nodes
    for k, v in d[0].items():
        G.add_edge(k[0], k[1], weight=(v * 10))

    fig, ax = plt.subplots(figsize=(15, 8))
    pos = nx.spring_layout(G, k=2)

    # Plot networks
    nx.draw_networkx(G, pos,
                     font_size=12,
                     width=3,
                     edge_color='grey',
                     node_color='purple',
                     with_labels = False,
                     ax=ax)

    # Create offset labels
    for key, value in pos.items():
        x, y = value[0]+.045, value[1]+.045
        ax.text(x, y,
                s=key,
                bbox=dict(facecolor='red', alpha=0.2),
                horizontalalignment='center', fontsize=13)
    plt.title(title)
    plt.savefig('../artefacts/' + title +'.eps', format='eps')
    plt.show()

# %% [markdown]
# # Publications

# %% [markdown]
# ## 1. Time/volume - line chart

# %%
df = pd.read_csv('../data_gc/bb_pulications.csv', index_col=0)

# %%
df['pub_year'] = df['bib'].apply(lambda x: ast.literal_eval(x)['pub_year'])
df_not_nan = df[df['pub_year']!= 'NA']

# %% [markdown]
# Note we lose a couple of publications because a number of them do not have publication year attached

# %%
#df_not_nan['pub_year'] = pd.to_datetime(df_not_nan['pub_year'])
df_not_nan['pub_year'] = df_not_nan['pub_year'].astype(int)
df_groupedby_date = df_not_nan.groupby('pub_year').count()
df_groupedby_date.reset_index(inplace=True)
# Out:
# /Users/Lono/miniconda3/envs/ethnicenv/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_groupedby_date['count'] = df_groupedby_date['container_type']

# %%
plt.figure(figsize=[17,4])
plt.xticks(rotation=45)
plt.title('Count of Publications Per Year Scraped June 2021 from Google Scholar: Benin Bronzes')
g = sns.barplot(data=df_groupedby_date, 
             x="pub_year", 
             y="count") 
ax=g
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=8, color='gray', xytext=(0, 5),
                textcoords='offset points')
_ = ax.set_ylim(0,120) #To make space for the annotations
plt.savefig('../artefacts/bb_gs_pubcount.eps', format='eps')

# %%
df_groupedby_date_2016 = df_groupedby_date[df_groupedby_date['pub_year'] > 2015]

# %%
plt.figure(figsize=[13,4])
plt.xticks(rotation=45)
plt.title('Count of Publications Per Year Post 2015 Scraped June 2021 from Google Scholar: Benin Bronzes')
g = sns.barplot(data=df_groupedby_date_2016, 
             x="pub_year", 
             y="count")
ax=g
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=11, color='gray', xytext=(0, 10),
                textcoords='offset points')
_ = ax.set_ylim(0,120) #To make space for the annotations
plt.savefig('../artefacts/bb_gs_pubcountpost2015.eps', format='eps')

# %% [markdown]
# ## 2. Keywords - Network diagram

# %%
def get_abstract(x):
    try:
        return ast.literal_eval(x)['abstract']
    except KeyError:
        return ''

# %%
df['abstract'] = df['bib'].apply(lambda x: get_abstract(x) )
df_abs = df[df['abstract']!= '']

# %% [markdown]
# We lose around 100 publications because they do not have abstracts

# %%
df_abs = ct.clean_tweets(df_abs,'abstract','lemma_text',
                general_clean=True,lemma=True,stem=False,remove_tag=False,remove_mention=False,
                remove_emoji=False, remove_stopword=True,min_length=1, untokenized_return=True)
# Out:
# time taken to clean tweets: 24.811201095581055s. Use the [lemma_text] column to perform your analysis/modeling on

# %%
df_abs = ct.clean_tweets(df_abs,'abstract','stem_text',
                general_clean=True,lemma=False,stem=True,remove_tag=False,remove_mention=False,
                remove_emoji=False, remove_stopword=True,min_length=1, untokenized_return=True)
# Out:
# time taken to clean tweets: 1.1775290966033936s. Use the [stem_text] column to perform your analysis/modeling on

# %%
draw_network(df_abs, 'lemma_text', 30, 'bb_abstracts_30')

# %%
draw_network(df_abs, 'lemma_text', 35, 'bb_abstracts_35')

# %%
draw_cooccur_network(df_abs, 35,'lemma_text', 'Networks of co-occurring words in Publication Abstracts: Benin Bronze')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## 3. Peoples vs citations vs ethnicity - CSV list, network diagram

# %%
from ethnicolr import pred_wiki_ln, pred_wiki_name

# %%
import unicodedata

# %%
def clean_name(name, surname=False):
    if surname == True:
        res = name.split(' ')[1:]
        surname = ' '.join(chars for chars in res)
        if surname == '':
            surname = name.split(' ')[0]
        name = surname
            
    name = name.lower()
    #remove phonetics
    name = ''.join((c for c in unicodedata.normalize('NFD', name) if unicodedata.category(c) != 'Mn'))
    return name

# %% [markdown]
# ### Authors African vs Not

# %%
df = pd.read_csv('../data_gc/bb_pulications.csv', index_col=0)

# %%
df.shape
# Out:
# (995, 13)

# %%
df['author'] = df['bib'].apply(lambda x: ast.literal_eval(x)['author'])

# %%
df['count'] = 1
dummy = df[['author', 'count']]
dummy1 = dummy.set_index('count').author.apply(pd.Series).stack().reset_index(level=0).rename(columns={0:'author'})

# %%
dummy1['author'] = dummy1['author'].apply(lambda x: clean_name(x) )

# %%
res = dummy1.groupby('author').agg('sum').reset_index().sort_values('count',ascending=False)
res['surname'] = res['author'].apply(lambda x: clean_name(x, True))

# %%
preds = pred_wiki_ln(res, "surname")
preds['african'] = preds['race'].apply(lambda x: 'African' if x=='GreaterAfrican,Africans' else ('African' if x== 'GreaterAfrican,Muslim' else 'Non-African'))

# %%
#manual fixes
#fix_list = ['ojaide', 'thebele', 'shyllon', 'sarr']
for name in fix_list:
    preds.loc[preds['surname']==name, 'african'] = 'African'
    
plt.figure(figsize=[18,4])
plt.xticks(rotation=45)
plt.title('Count of Publications Per Author (top 35) Scraped June 2021 from Google Scholar: Benin Bronzes')
g = sns.barplot(data=preds[0:35], 
             x="author", 
             y="count",
             hue="african") 
ax=g
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=8, color='gray', xytext=(0, 5),
                textcoords='offset points')
_ = ax.set_ylim(0,18) #To make space for the annotations
plt.savefig('../artefacts/bb_gs_pubsperauthor.eps', format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
preds.to_csv('bb_publishers.csv')

# %%
ratio = preds.groupby('african').agg('sum').reset_index()
plt.figure(figsize=[5,6])
plt.xticks(rotation=45)
plt.title('Count of Publications Per Ethnicity Scraped June 2021 from Google Scholar: Benin Bronzes')
g = sns.barplot(data=ratio, 
             x="african", 
             y="count",
             hue="african") 
ax=g
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=8, color='gray', xytext=(0, 5),
                textcoords='offset points')
_ = ax.set_ylim(0,1195) #To make space for the annotations
plt.savefig('../artefacts/bb_gs_pubsperethnicity.eps', format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
df['pub_year'] = df['bib'].apply(lambda x: ast.literal_eval(x)['pub_year'])
df_not_nan = df[df['pub_year']!= 'NA']
df_not_nan = df_not_nan[df_not_nan['pub_year'].astype(int) > 2015]
year_author = df_not_nan.set_index('pub_year', append=True).author.apply(pd.Series).stack().reset_index(level=[0, 2], drop=True).reset_index()
year_author['surname'] = year_author[0].apply(lambda x: clean_name(x, True))
preds = pred_wiki_ln(year_author, "surname")
preds['african'] = preds['race'].apply(lambda x: 'African' if x=='GreaterAfrican,Africans' else ('African' if x== 'GreaterAfrican,Muslim' else 'Non-African'))
#manual fixes
for name in fix_list:
    preds.loc[preds['surname']==name, 'african'] = 'African'
preds['count'] = 1
ratio = preds.groupby(['pub_year','african']).agg('sum').reset_index()

# %%
catp = sns.catplot(x = "pub_year",   # x variable name
            y = "count",      # y variable name
            hue = "african",  # group variable name
            data = ratio,     # dataframe to plot
            kind = "bar")

# This will merge columns in order of the chart
vals = ratio[ratio['african'] == 'African']['count'].to_list() + ratio[ratio['african'] == 'Non-African']['count'].to_list()
    
# Add the values on top of each correct bar
i = 0
for idx, p in enumerate(catp.ax.patches):
    height = p.get_height()
    catp.ax.text(p.get_x()+p.get_width()/2.,
            height + height*.03,
            vals[idx],
            ha="center")
_ = catp.ax.set_ylim(0,120) #To make space for the annotations
plt.xticks(rotation=45)
plt.suptitle('Ethnicity over the years: Benin Bronze', size=16, y=1.12)
#plt.tight_layout()
plt.show()
plt.savefig('../artefacts/bb_gs_ethnicityoyears.eps', format='eps')

# %% [markdown]
# ### Authors vs citations

# %% [markdown]
# These are the publications that have citations and only from 2016. A whole lot less publications from the total collected

# %%
df = pd.read_csv('../data_gc/bb_pub_citations.csv', index_col=0)
df['author'] = df['bib'].apply(lambda x: ast.literal_eval(x)['author'])
df['citing_authors'] = df['citations'].apply(lambda x: [item['author'] for item in ast.literal_eval(x)])
dummy = df[['author', 'num_citations']]

# %%
dummy1 = dummy.set_index('num_citations').author.apply(pd.Series).stack().reset_index(level=0).rename(columns={0:'author'})
dummy1['author'] = dummy1['author'].apply(lambda x: clean_name(x) )

# %%
res = dummy1.groupby('author').agg('sum').reset_index().sort_values('num_citations',ascending=False)
res['surname'] = res['author'].apply(lambda x: clean_name(x, True))

# %%
#ethnicity thing needs a specific dev environment
#https://ethnicolr.readthedocs.io/ethnicolr.html
preds = pred_wiki_ln(res, "surname")
preds['african'] = preds['race'].apply(lambda x: 'African' if x=='GreaterAfrican,Africans' else ('African' if x== 'GreaterAfrican,Muslim' else 'Non-African'))

# %%
#manual fixes
for name in fix_list:
    preds.loc[preds['surname']==name, 'african'] = 'African'

# %%
plt.figure(figsize=[18,4])
plt.xticks(rotation=45)
plt.title('Count of Citations Per Author (top 35) Scraped June 2021 from Google Scholar: Benin Bronzes')
g = sns.barplot(data=preds[0:40], 
             x="author", 
             y="num_citations",
             hue="african") 
ax=g
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=8, color='gray', xytext=(0, 5),
                textcoords='offset points')
_ = ax.set_ylim(0,580) #To make space for the annotations
plt.savefig('../artefacts/bb_gs_citesperauthor.eps', format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
ratio = preds.groupby('african').agg('sum').reset_index()

# %%
plt.figure(figsize=[5,6])
plt.xticks(rotation=45)
plt.title('Count of Citations Per Ethnicity Scraped June 2021 from Google Scholar: Benin Bronzes')
g = sns.barplot(data=ratio, 
             x="african", 
             y="num_citations",
             hue="african") 
ax=g
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=8, color='gray', xytext=(0, 5),
                textcoords='offset points')
_ = ax.set_ylim(0,4500) #To make space for the annotations
plt.savefig('../artefacts/bb_gs_citesperethnicity.eps', format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ### Citation Network graph

# %%
from collections import Counter
import nxviz as nv

# %%
#note this requires the graph env
# also this is not working because I did not scrape enough sitations 
# for most of the publications that have above 20 citations

# %%
df = pd.read_csv('../data_gc/bb_pub_citations.csv', index_col=0)

# %%
print(df[df['num_citations']>20].shape)
df[df['num_citations']>20]
# Out:
# (24, 15)
#     container_type                                        source  \
# 5      Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 6      Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 11     Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 31     Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 37     Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 44     Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 48     Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 71     Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 86     Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 97     Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 98     Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 101    Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 108    Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 112    Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 114    Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 115    Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 118    Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 119    Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 120    Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 121    Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 123    Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 126    Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 128    Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
# 131    Publication  PublicationSource.PUBLICATION_SEARCH_SNIPPET
#
#                                                    bib  filled  gsrank  \
# 5    {'title': 'The Dutch Moment: War, Trade, and S...   False     864
# 6    {'title': 'Peoples of the Niger-Benue Confluen...   False     875
# 11   {'title': 'Water from the rock: Black resistan...   False     921
# 31   {'title': 'Keeping Their Marbles: How the Trea...   False      90
# 37   {'title': 'Treasures in trusted hands: negotia...   False     121
# 44   {'title': 'The colonial archival imaginaire at...   False     167
# 48   {'title': 'Situational ethics and engaged prac...   False     188
# 71   {'title': 'Restituer le patrimoine africain', ...   False     349
# 86   {'title': 'Learning at the museum frontiers: I...   False     425
# 97   {'title': 'Age of Empires', 'author': ['R Aldr...   False     514
# 98   {'title': 'Paths to inclusive political instit...   False     517
# 101  {'title': 'Reparations to Africa', 'author': [...   False     537
# 108  {'title': "The empire in one city?: Liverpool'...   False     592
# 112  {'title': 'The groundings with my brothers', '...   False     641
# 114  {'title': 'Consolidation of democracy in Afric...   False     653
# 115  {'title': "L'Exposition coloniale de 1931", 'a...   False     670
# 118  {'title': "Pour une ethnoarchéologie théorique...   False     693
# 119  {'title': 'Mumbo jumbo', 'author': ['I Reed'],...   False     699
# 120  {'title': 'The Tale of the Harmattan', 'author...   False     704
# 121  {'title': 'Unsettled History: Making South Afr...   False     710
# 123  {'title': 'The narrow corridor: States, societ...   False     714
# 126  {'title': '" Eat the Heart of the Infidel": Th...   False     729
# 128  {'title': 'Coins and currency: an historical e...   False     741
# 131  {'title': 'Preserving Korean Music: Intangible...   False     762
#
#                                                pub_url  \
# 5                                                  NaN
# 6    https://books.google.com/books?hl=en&lr=&id=n8...
# 11   https://books.google.com/books?hl=en&lr=&id=UF...
# 31   https://books.google.com/books?hl=en&lr=&id=TA...
# 37   https://library.oapen.org/handle/20.500.12657/...
# 44   https://onlinelibrary.wiley.com/doi/abs/10.111...
# 48   https://www.taylorfrancis.com/chapters/edit/10...
# 71                                                 NaN
# 86   https://books.google.com/books?hl=en&lr=&id=Ze...
# 97                                                 NaN
# 98   https://link.springer.com/chapter/10.1007/978-...
# 101  https://www.degruyter.com/document/doi/10.9783...
# 108                                                NaN
# 112  https://books.google.com/books?hl=en&lr=&id=bO...
# 114  https://books.google.com/books?hl=en&lr=&id=wo...
# 115                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120  https://books.google.com/books?hl=en&lr=&id=M5...
# 121                                                NaN
# 123                                                NaN
# 126  https://books.google.com/books?hl=en&lr=&id=_i...
# 128  https://books.google.com/books?hl=en&lr=&id=r7...
# 131  https://www.taylorfrancis.com/books/mono/10.43...
#
#                                 author_id  num_citations  \
# 5                                    ['']             78
# 6                            ['', '', '']             30
# 11                                   ['']            523
# 31                                   ['']             60
# 37                                   ['']             26
# 44                                   ['']             21
# 48                                   ['']             62
# 71                               ['', '']             52
# 86                                   ['']            187
# 97                                   ['']             29
# 98       ['l9Or8EMAAAAJ', 'rNHDppMAAAAJ']             87
# 101                      ['ac45OdYAAAAJ']             73
# 108                              ['', '']             52
# 112                                  ['']            472
# 114                  ['', 'YyrS-aoAAAAJ']             26
# 115                              ['', '']            172
# 118                                  ['']             77
# 119                                  ['']            446
# 120                                  ['']             30
# 121  ['pgRSe2YAAAAJ', 'KezXOMkAAAAJ', '']             35
# 123      ['l9Or8EMAAAAJ', 'rNHDppMAAAAJ']            236
# 126                                  ['']             73
# 128                                  ['']             23
# 131                      ['J8gJQJ8AAAAJ']            105
#
#                                         url_scholarbib  \
# 5    /scholar?q=info:KWdYsRx0USEJ:scholar.google.co...
# 6    /scholar?q=info:YsCFPCwFdsIJ:scholar.google.co...
# 11   /scholar?q=info:Vx30KpF2BuYJ:scholar.google.co...
# 31   /scholar?q=info:Bv4VIEsaMQ0J:scholar.google.co...
# 37   /scholar?q=info:XOqfkp6ZujsJ:scholar.google.co...
# 44   /scholar?q=info:u5Vh96po1RkJ:scholar.google.co...
# 48   /scholar?q=info:XD_6ENMiSWIJ:scholar.google.co...
# 71   /scholar?q=info:q3YtDEkk3rkJ:scholar.google.co...
# 86   /scholar?q=info:bnSEZN73aNsJ:scholar.google.co...
# 97   /scholar?q=info:xnOUDb5BaPMJ:scholar.google.co...
# 98   /scholar?q=info:u7pqFvkRh70J:scholar.google.co...
# 101  /scholar?q=info:VmitLgWWKZYJ:scholar.google.co...
# 108  /scholar?q=info:lJXt2KSzsmAJ:scholar.google.co...
# 112  /scholar?q=info:ryYSnS_I7p8J:scholar.google.co...
# 114  /scholar?q=info:ZJGVH7FiQIsJ:scholar.google.co...
# 115  /scholar?q=info:I_2LfFJhYV4J:scholar.google.co...
# 118  /scholar?q=info:Fglmxm6LRZEJ:scholar.google.co...
# 119  /scholar?q=info:_JiMOgIpoK0J:scholar.google.co...
# 120  /scholar?q=info:3mRti5WIKA0J:scholar.google.co...
# 121  /scholar?q=info:B3EMCUO9scIJ:scholar.google.co...
# 123  /scholar?q=info:q-7oqZrCEpIJ:scholar.google.co...
# 126  /scholar?q=info:tS7CP4e8GX4J:scholar.google.co...
# 128  /scholar?q=info:JedwuWC3UpYJ:scholar.google.co...
# 131  /scholar?q=info:1uZWoJ0fsLQJ:scholar.google.co...
#
#                                          url_add_sclib  \
# 5    /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 6    /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 11   /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 31   /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 37   /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 44   /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 48   /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 71   /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 86   /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 97   /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 98   /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 101  /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 108  /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 112  /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 114  /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 115  /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 118  /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 119  /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 120  /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 121  /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 123  /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 126  /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 128  /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
# 131  /citations?hl=en&xsrf=&continue=/scholar%3Fq%3...
#
#                                            citedby_url  \
# 5    /scholar?cites=2400827742948452137&as_sdt=5,33...
# 6    /scholar?cites=14012392978161975394&as_sdt=5,3...
# 11   /scholar?cites=16575065844446666071&as_sdt=5,3...
# 31   /scholar?cites=950569906315066886&as_sdt=5,33&...
# 37   /scholar?cites=4303921300249766492&as_sdt=5,33...
# 44   /scholar?cites=1861509104491664827&as_sdt=5,33...
# 48   /scholar?cites=7082230178935095132&as_sdt=5,33...
# 71   /scholar?cites=13393182238001952427&as_sdt=5,3...
# 86   /scholar?cites=15810159026425328750&as_sdt=5,3...
# 97   /scholar?cites=17539341033321821126&as_sdt=5,3...
# 98   /scholar?cites=13656904156544940731&as_sdt=5,3...
# 101  /scholar?cites=10820344528736446550&as_sdt=5,3...
# 108  /scholar?cites=6967829094091036052&as_sdt=5,33...
# 112  /scholar?cites=11524368603311908527&as_sdt=5,3...
# 114  /scholar?cites=10034128482660094308&as_sdt=5,3...
# 115  /scholar?cites=6800823919210921251&as_sdt=5,33...
# 118  /scholar?cites=10467926216783825174&as_sdt=5,3...
# 119  /scholar?cites=12511044854384204028&as_sdt=5,3...
# 120  /scholar?cites=948157897432196318&as_sdt=5,33&...
# 121  /scholar?cites=14029202409848074503&as_sdt=5,3...
# 123  /scholar?cites=10525689248649637547&as_sdt=5,3...
# 126  /scholar?cites=9086501012272983733&as_sdt=5,33...
# 128  /scholar?cites=10831921679835391781&as_sdt=5,3...
# 131  /scholar?cites=13019941284588480214&as_sdt=5,3...
#
#                                   url_related_articles  \
# 5    /scholar?q=related:KWdYsRx0USEJ:scholar.google...
# 6    /scholar?q=related:YsCFPCwFdsIJ:scholar.google...
# 11   /scholar?q=related:Vx30KpF2BuYJ:scholar.google...
# 31   /scholar?q=related:Bv4VIEsaMQ0J:scholar.google...
# 37   /scholar?q=related:XOqfkp6ZujsJ:scholar.google...
# 44   /scholar?q=related:u5Vh96po1RkJ:scholar.google...
# 48   /scholar?q=related:XD_6ENMiSWIJ:scholar.google...
# 71   /scholar?q=related:q3YtDEkk3rkJ:scholar.google...
# 86   /scholar?q=related:bnSEZN73aNsJ:scholar.google...
# 97   /scholar?q=related:xnOUDb5BaPMJ:scholar.google...
# 98   /scholar?q=related:u7pqFvkRh70J:scholar.google...
# 101  /scholar?q=related:VmitLgWWKZYJ:scholar.google...
# 108  /scholar?q=related:lJXt2KSzsmAJ:scholar.google...
# 112  /scholar?q=related:ryYSnS_I7p8J:scholar.google...
# 114  /scholar?q=related:ZJGVH7FiQIsJ:scholar.google...
# 115  /scholar?q=related:I_2LfFJhYV4J:scholar.google...
# 118  /scholar?q=related:Fglmxm6LRZEJ:scholar.google...
# 119  /scholar?q=related:_JiMOgIpoK0J:scholar.google...
# 120  /scholar?q=related:3mRti5WIKA0J:scholar.google...
# 121  /scholar?q=related:B3EMCUO9scIJ:scholar.google...
# 123  /scholar?q=related:q-7oqZrCEpIJ:scholar.google...
# 126  /scholar?q=related:tS7CP4e8GX4J:scholar.google...
# 128  /scholar?q=related:JedwuWC3UpYJ:scholar.google...
# 131  /scholar?q=related:1uZWoJ0fsLQJ:scholar.google...
#
#                                             eprint_url  pub_year  \
# 5                                                  NaN      2016
# 6                                                  NaN      2017
# 11                                                 NaN      2020
# 31                                                 NaN      2016
# 37   https://library.oapen.org/bitstream/handle/20....      2017
# 44   https://www.academia.edu/download/50920336/Soc...      2016
# 48                                                 NaN      2020
# 71                                                 NaN      2018
# 86                                                 NaN      2016
# 97                                                 NaN      2020
# 98   https://thepearsoninstitute.org/sites/default/...      2016
# 101                                                NaN      2018
# 108                                                NaN      2017
# 112                                                NaN      2019
# 114                                                NaN      2017
# 115                                                NaN      2021
# 118                                                NaN      2021
# 119                                                NaN      2017
# 120                                                NaN      2016
# 121                                                NaN      2017
# 123  https://www.academia.edu/download/64010389/JUI...      2020
# 126                                                NaN      2018
# 128                                                NaN      2019
# 131                                                NaN      2017
#
#                                              citations
# 5    [{'title': 'The apocalypse of settler colonial...
# 6    [{'title': 'Parties and politics in Northern N...
# 11   [{'title': 'The churching of America, 1776-200...
# 31   [{'title': 'The archaeology of human bones', '...
# 37   [{'title': 'Radical empathy, the imaginary and...
# 44   [{'title': 'Archival encounters: rethinking ac...
# 48   [{'title': 'Conflicting rationalities: Implica...
# 71   [{'title': 'Transnational foreign cultural pol...
# 86   [{'title': 'Geographies of alternative educati...
# 97   [{'title': 'The longest journey: Southeast Asi...
# 98   [{'title': 'States and economic growth: Capaci...
# 101  [{'title': 'A theory of intergenerational just...
# 108  [{'title': "'Comfort'and Conviction: A Respons...
# 112  [{'title': 'Resistance through rituals: Youth ...
# 114  [{'title': 'Public opinion, democracy, and mar...
# 115  [{'title': 'Colonization: A global history', '...
# 118  [{'title': 'Reclaiming archaeology', 'author':...
# 119  [{'title': 'A poetics of postmodernism: Histor...
# 120  [{'title': 'Examining canonisation in modern A...
# 121  [{'title': 'What is public history globally?: ...
# 123  [{'title': 'The public policy process', 'autho...
# 126  [{'title': 'Historical dictionary of Nigeria',...
# 128  [{'title': 'Chinese Money in Global Context', ...
# 131  [{'title': 'Primitive selves: Koreana in the J...

# %%
df['author'] = df['bib'].apply(lambda x: ast.literal_eval(x)['author'])
df['citing_authors'] = df['citations'].apply(lambda x: [item['author'] for item in ast.literal_eval(x)])

# %%
df = df[['author', 'citing_authors']]
#need to explode twice to extract citation lists adequately
df = df.explode('author')
df = df.explode('citing_authors')
df = df.explode('citing_authors')

# %%
df['count'] = 1

# %%
authors_flat = [
    author
    for author in list(df["author"].dropna())
]

# %%
G = nx.from_pandas_edgelist(
    df, source="author", target="citing_authors", edge_attr="count"
)

# Limit to TOP 50 authors
top50authors = pd.DataFrame.from_records(
    Counter(authors_flat).most_common(50), columns=["author", "count"]
)

# %%
top50_nodes = (n for n in list(G.nodes()) if n in list(top50authors["author"]))

G_50 = G.subgraph(top50_nodes)

for n in G_50.nodes():
    G_50.nodes[n]["citations"] = int(
        top50authors[top50authors["author"] == n]["count"]
    )

# %%
c = nv.CircosPlot(
    G_50,
    dpi=600,
    node_grouping="citations",
    edge_width="count",
    figsize=(20, 20),
    node_color="citations",
    node_labels=True,
)
c.draw()
plt.show()

# %% [markdown]
# # Media

# %%
df = pd.read_csv('../data_gc/bb_google_content172_cleaned.csv', index_col=0)

# %% [markdown]
# ### 1. Keywords - Network diagram: Pelonomi

# %% [markdown]
# The green newtork diagrams are with regards to word similarity based on the texts

# %%
print(df.shape)
df_text = df[~df['text'].isna()]
df_text.shape
# Out:
# (172, 7)
# (164, 7)

# %% [markdown]
# So, we lost a couple of articles because we could not get text from them (their text is NaN)

# %%
draw_network(df_text, 'lemma_text', 20000, 'bb_gc_content20000') #20000

# %%
draw_network(df_text, 'lemma_text', 10000, 'bb_gc_content10000') #10000

# %%
draw_network(df_text, 'lemma_text', 5000, 'bb_gc_content5000') #10000

# %%
df_not_nan = df[~df['lemma_text'].isna()]

# %%
draw_cooccur_network(df_not_nan, 45,'lemma_text', 'Networks of co-occurring words in Media Articles')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
get_wordcloud(df_text, 'lemma_text', 'bb_content_wc')

# %% [markdown]
# ### 2. Peoples vs mentions vs ethnicity - CSV list, bar chart: Pelonomi

# %%
#this section requires Spacy
#!pip install spacy
#!python -m spacy download en_core_web_sm

# %% [markdown]
# #### Get names first

# %%
import spacy

# %%
from nltk.corpus import stopwords

# %%
def NER(text):
    """Takes in a string of text and returns a dataframe of all named entities
    
        Args:
            :param text: string, a string containing entire corpus
    """
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)

    entities = []
    labels = []
    position_start = []
    position_end = []

    for ent in doc.ents:
        entities.append(ent)
        labels.append(ent.label_)
        #position_start.append(ent.start_char)
        #position_end.append(ent.end_char)

    df = pd.DataFrame({'Entities':entities,'Labels':labels,'Position_Start':position_start, 'Position_End':position_end})

    return df

# %%
df.sample(10)
# Out:
#                                                  title  \
# 124  University Of Aberdeen And German Museums To R...
# 91   The Haunting History of the Benin Bronzes - Th...
# 9    Germany Will Return Benin Bronzes to Nigeria i...
# 41   Are the Benin Bronzes On Their Way to Repatria...
# 105  The Brutish Museums : The Benin Bronzes, Colon...
# 58   The Brutish Museums: the Benin Bronzes, Coloni...
# 50   The Brutish Museums: The Benin Bronzes ... - A...
# 375  The Brutish Museums: The Benin Bronzes ... - A...
# 95   Germany to return Benin Bronzes, looted during...
# 72   The Brutish Museums: The Benin Bronzes, Coloni...
#
#                                                   link  \
# 124  https://www.thevintagenews.com/2021/05/05/beni...
# 91   https://artangle.libsyn.com/the-haunting-histo...
# 9    https://www.smithsonianmag.com/smart-news/majo...
# 41   https://www.widewalls.ch/magazine/benin-bronze...
# 105  https://housmans.com/product/the-brutish-museu...
# 58   https://www.kenyon.edu/events/the-brutish-muse...
# 50   https://www.amazon.fr/Brutish-Museums-Colonial...
# 375  https://www.amazon.co.uk/Brutish-Museums-Colon...
# 95   https://thegrio.com/2021/05/02/germany-to-retu...
# 72   https://africa.berkeley.edu/brutish-museums-be...
#
#                                                   text        date  \
# 124  The Benin Bronzes is the name given to over a ...         NaN
# 91   Feb 25, 2021\nFor decades, one of the most urg...         NaN
# 9    SIGN UP for our newsletter\n“We face a histori...  2021-04-30
# 41   African nations have long demanded the restitu...         NaN
# 105  Description\nby Hicks, Dan | The arts\nPublish...         NaN
# 58   The Brutish Museums: the Benin Bronzes, Coloni...         NaN
# 50   The centre-piece, the prize exhibit of the boo...         NaN
# 375  The centre-piece, the prize exhibit of the boo...         NaN
# 95   Germany to return Benin Bronzes, looted during...         NaN
# 72                                                 NaN         NaN
#
#       html_date                                         lemma_text  \
# 124  2021-05-05  benin bronze name give thousand metal plaque s...
# 91   2021-02-25  feb 25 2021 decade one urgent moral debate mus...
# 9    2021-04-30  sign newsletter we face historic moral respons...
# 41   2021-04-13  african nation long demand restitution poach c...
# 105  2020-11-03  description hick dan art publish 20082020 plut...
# 58   2021-04-21  brutish museum benin bronze colonial violence ...
# 50   2021-05-19  centre piece prize exhibit book capture city b...
# 375  2021-03-12  centre piece prize exhibit book capture city b...
# 95   2021-05-02  germany return benin bronze loot colonial era ...
# 72          NaN                                                NaN
#
#                                              stem_text
# 124  benin bronz name given thousand metal plaqu sc...
# 91   feb 25 2021 decad one urgent moral debat museu...
# 9    sign newslett we face histor moral respons shi...
# 41   african nation long demand restitut poach cult...
# 105  descript hick dan art publish 20082020 pluto p...
# 58   brutish museum benin bronz coloni violenc cult...
# 50   centr piec prize exhibit book captur citi beni...
# 375  centr piec prize exhibit book captur citi beni...
# 95   germani return benin bronz loot coloni era nig...
# 72                                                 NaN

# %%
#there is a couple of nans in here (8 articles in total) including two Japanese articles hahaha
df = df[~df['text'].isna()]
text = ''.join(x for x in df['text'])

# %%
#stopwords_eng = stopwords.words('english')
#tokenized_doc = text.split()
no_stopwords = " ".join([item for item in tokenized_doc if item not in stopwords_eng])

# %%
ner_df = NER(text[0:1000000])
ner_df2 = NER(text[1000000:])

# %%
ner = pd.concat([ner_df, ner_df2])

# %%
ner['count'] = 1
ner.groupby('Entities').agg('sum').reset_index().sort_values('count',ascending=False)
# Out:
#                     Entities  Position_Start  Position_End  count
# 0           (Benin, Bronzes)               0            13      1
# 11520            (Stuttgart)          653031        653040      1
# 11506               (German)          652511        652517      1
# 11507          (Heiko, Maas)          652535        652545      1
# 11508               (German)          652682        652688      1
# ...                      ...             ...           ...    ...
# 5762   (Rutgers, University)          280117        280135      1
# 5763                  (2009)          280140        280144      1
# 5764                  (EHSS)          280175        280179      1
# 5765                 (Paris)          280181        280186      1
# 17270          (The, Square)          999985        999995      1
#
# [17271 rows x 4 columns]

# %%
ner = ner[(ner['Labels'] == 'PERSON')]

# %%
ner['Entities'] = ner['Entities'].astype(str)
ner = ner.groupby('Entities').agg('sum').reset_index().sort_values('count',ascending=False)

# %%
exl_list = ['Benin', 'British', 'Museums', 'Benin Bronze', 'Benin Bronzes']
ner = ner[~ner['Entities'].isin(exl_list)]
ner.head(40)
# Out:
#                     Entities  Position_Start  Position_End  count
# 237                Dan Hicks        29763012      29763633     69
# 886           Queen Victoria         9489217       9489539     23
# 318          Emmanuel Macron        12016735      12017050     21
# 290                 Dunstone         1686090       1686258     21
# 251             David Adjaye         7089944       7090196     21
# 441               Heiko Maas         9128230       9128430     20
# 566                 K. Opoku        11460469      11460605     17
# 807                 Ogundele         7147452       7147580     16
# 679                   Macron         8036348       8036438     15
# 89                   Awoyemi         1218050       1218155     15
# 1056      Victor Ehikhamenor         5659887       5660139     14
# 735         Monika Gruetters         5975211       5975435     14
# 100   Barbara Plankensteiner         7333482       7333790     14
# 1110                Zimmerer         6058874       6058978     13
# 414           Godwin Obaseki         5516441       5516623     13
# 155                     Bini         3792040       3792088     12
# 745                   Museen         9985552       9985624     12
# 1070                  Walker         1495976       1496048     12
# 737          Monika Grütters         2976729       2976894     11
# 351             Felwine Sarr         5837166       5837298     11
# 696              Mark Walker         4349849       4349959     10
# 350        Felix von Luschan         6651035       6651205     10
# 629              Kwame Opoku         5805377       5805476      9
# 458        Hermann Parzinger         4409329       4409482      9
# 909           Richard Burton         2729697       2729823      9
# 1025                  Thomas         8193282       8193336      9
# 557                     Juju         2619041       2619073      8
# 848            Peju Layiwola         2934872       2934976      8
# 159                Boisragon         2614505       2614577      8
# 42       Alhaji Lai Mohammed         3861007       3861159      8
# 663                    Locke         2614793       2614833      8
# 288                  Dracula         2633105       2633161      8
# 556         Juergen Zimmerer         3834338       3834466      8
# 800           Oba Ovonramwen         3326929       3327027      7
# 776              Neil Curtis         4830777       4830854      7
# 329            Errol Francis         4129201       4129292      7
# 673                  Luschan         5603170       5603219      7
# 777           Neil MacGregor         3088873       3088971      7
# 938               Rothenbaum         3023923       3023983      6
# 56            Andreas Görgen         2277749       2277833      6

# %%
ner[['Entities', 'count']].to_csv('bb_media_people_mentions.csv')

# %% [markdown]
# I wrote to file here, started the ethnic env then read in the file and continued

# %%
ner = pd.read_csv('../data_gc/bb_media_people_mentions.csv', index_col=0)

# %%
ner
# Out:
#                                           Entities  count
# 237                                      Dan Hicks     69
# 886                                 Queen Victoria     23
# 318                                Emmanuel Macron     21
# 290                                       Dunstone     21
# 251                                   David Adjaye     21
# 441                                     Heiko Maas     20
# 566                                       K. Opoku     17
# 807                                       Ogundele     16
# 679                                         Macron     15
# 89                                         Awoyemi     15
# 1056                            Victor Ehikhamenor     14
# 735                               Monika Gruetters     14
# 100                         Barbara Plankensteiner     14
# 1110                                      Zimmerer     13
# 414                                 Godwin Obaseki     13
# 155                                           Bini     12
# 745                                         Museen     12
# 1070                                        Walker     12
# 737                                Monika Grütters     11
# 351                                   Felwine Sarr     11
# 696                                    Mark Walker     10
# 350                              Felix von Luschan     10
# 629                                    Kwame Opoku      9
# 458                              Hermann Parzinger      9
# 909                                 Richard Burton      9
# 1025                                        Thomas      9
# 557                                           Juju      8
# 848                                  Peju Layiwola      8
# 159                                      Boisragon      8
# 42                             Alhaji Lai Mohammed      8
# ...                                            ...    ...
# 168                                         Bricks      1
# 597                                  Klaus Lederer      1
# 598                                   Kofo Adeleke      1
# 574                                    Katrin Sieg      1
# 573                                  Katie Fleming      1
# 172                                        Bronson      1
# 178                                      Bryn Mawr      1
# 547                                Jos van Beurden      1
# 181   Bundeskulturstaatsministerin Monika Grütters      1
# 549                Joseph Conrad Heart of Darkness      1
# 550                                Joseph Eboreime      1
# 551                               Joseph Egharevba      1
# 552                                    Joshua Wong      1
# 553                           José Luis Villacañas      1
# 554                                     Joy Bivins      1
# 180                                   Builth Wells      1
# 179                                         Buhari      1
# 558                              Jules de Goncourt      1
# 571                                    Kate Osakue      1
# 559                                   Julie Hudson      1
# 560                                 Julie Omoregie      1
# 561                                        Julieta      1
# 562                               Juliette Binoche      1
# 563                                Justin Gentilis      1
# 564                                Jörg Häntzschel      1
# 175                              Bruce Onobrakpeya      1
# 568                                   Karel Arnaut      1
# 569                                 Karen Frascona      1
# 1                                 8 Meyer Schapiro      1
# 1139                                     à Londres      1
#
# [1136 rows x 2 columns]

# %%
ner['surname'] = ner['Entities'].apply(lambda x: clean_name(x, True))

# %%
ner = ner[~ner['surname'].str.contains("\/")]
ner = ner[~ner['surname'].str.contains("\(")]
ner = ner[~ner['surname'].str.contains("\.")]
ner = ner[~ner['surname'].str.contains("\|")]
ner = ner[~ner['surname'].str.contains("\--")]
ner = ner[~ner['surname'].str.contains("\- ")]
ner = ner[~ner['surname'].str.contains("ii")]
ner = ner[~ner['surname'].str.contains("iv")]
ner['surname'] = ner['surname'].str.replace("'s'", '')
ner['has_nums'] = ner['surname'].apply(lambda x: len(re.findall('\d+', x)))
ner = ner[ner['has_nums'] ==0]
ner['no_words'] = ner['surname'].apply(lambda x: len(x.split()))
ner = ner[ner['no_words'] <=3]
ner['no_letters'] = ner['surname'].apply(lambda x: len(x))
ner = ner[ner['no_letters'] >1]

# %%
preds2 = pred_wiki_ln(ner, "surname")

# %%
preds2
# Out:
#                                           Entities  count          surname  \
# 237                                      Dan Hicks     69            hicks
# 886                                 Queen Victoria     23         victoria
# 318                                Emmanuel Macron     21           macron
# 290                                       Dunstone     21         dunstone
# 251                                   David Adjaye     21           adjaye
# 441                                     Heiko Maas     20             maas
# 566                                       K. Opoku     17            opoku
# 807                                       Ogundele     16         ogundele
# 679                                         Macron     15           macron
# 89                                         Awoyemi     15          awoyemi
# 1056                            Victor Ehikhamenor     14      ehikhamenor
# 735                               Monika Gruetters     14        gruetters
# 100                         Barbara Plankensteiner     14   plankensteiner
# 1110                                      Zimmerer     13         zimmerer
# 414                                 Godwin Obaseki     13          obaseki
# 155                                           Bini     12             bini
# 745                                         Museen     12           museen
# 1070                                        Walker     12           walker
# 737                                Monika Grütters     11         grutters
# 351                                   Felwine Sarr     11             sarr
# 696                                    Mark Walker     10           walker
# 350                              Felix von Luschan     10      von luschan
# 629                                    Kwame Opoku      9            opoku
# 458                              Hermann Parzinger      9        parzinger
# 909                                 Richard Burton      9           burton
# 1025                                        Thomas      9           thomas
# 557                                           Juju      8             juju
# 848                                  Peju Layiwola      8         layiwola
# 159                                      Boisragon      8        boisragon
# 42                             Alhaji Lai Mohammed      8     lai mohammed
# ...                                            ...    ...              ...
# 594                                          Kings      1            kings
# 595                                 Kingsley Inneh      1            inneh
# 168                                         Bricks      1           bricks
# 597                                  Klaus Lederer      1          lederer
# 598                                   Kofo Adeleke      1          adeleke
# 574                                    Katrin Sieg      1             sieg
# 573                                  Katie Fleming      1          fleming
# 172                                        Bronson      1          bronson
# 178                                      Bryn Mawr      1             mawr
# 547                                Jos van Beurden      1      van beurden
# 181   Bundeskulturstaatsministerin Monika Grütters      1  monika grutters
# 550                                Joseph Eboreime      1         eboreime
# 551                               Joseph Egharevba      1        egharevba
# 552                                    Joshua Wong      1             wong
# 553                           José Luis Villacañas      1  luis villacanas
# 180                                   Builth Wells      1            wells
# 179                                         Buhari      1           buhari
# 558                              Jules de Goncourt      1      de goncourt
# 571                                    Kate Osakue      1           osakue
# 559                                   Julie Hudson      1           hudson
# 560                                 Julie Omoregie      1         omoregie
# 561                                        Julieta      1          julieta
# 562                               Juliette Binoche      1          binoche
# 563                                Justin Gentilis      1         gentilis
# 564                                Jörg Häntzschel      1       hantzschel
# 175                              Bruce Onobrakpeya      1      onobrakpeya
# 568                                   Karel Arnaut      1           arnaut
# 569                                 Karen Frascona      1         frascona
# 1                                 8 Meyer Schapiro      1   meyer schapiro
# 1139                                     à Londres      1          londres
#
#       has_nums  no_words  no_letters                                   race  \
# 237          0         1           5                GreaterEuropean,British
# 886          0         1           8   GreaterEuropean,WestEuropean,Italian
# 318          0         1           6                GreaterEuropean,British
# 290          0         1           8                GreaterEuropean,British
# 251          0         1           6                GreaterAfrican,Africans
# 441          0         1           4  GreaterEuropean,WestEuropean,Germanic
# 566          0         1           5                GreaterEuropean,British
# 807          0         1           8                GreaterAfrican,Africans
# 679          0         1           6                GreaterEuropean,British
# 89           0         1           7                GreaterAfrican,Africans
# 1056         0         1          11               Asian,IndianSubContinent
# 735          0         1           9                GreaterEuropean,British
# 100          0         1          14                 GreaterEuropean,Jewish
# 1110         0         1           8                GreaterEuropean,British
# 414          0         1           7        Asian,GreaterEastAsian,Japanese
# 155          0         1           4   GreaterEuropean,WestEuropean,Italian
# 745          0         1           6                GreaterAfrican,Africans
# 1070         0         1           6                GreaterEuropean,British
# 737          0         1           8                GreaterEuropean,British
# 351          0         1           4                GreaterEuropean,British
# 696          0         1           6                GreaterEuropean,British
# 350          0         2          11  GreaterEuropean,WestEuropean,Germanic
# 629          0         1           5                GreaterEuropean,British
# 458          0         1           9                 GreaterEuropean,Jewish
# 909          0         1           6                GreaterEuropean,British
# 1025         0         1           6                GreaterEuropean,British
# 557          0         1           4       Asian,GreaterEastAsian,EastAsian
# 848          0         1           8                GreaterAfrican,Africans
# 159          0         1           9    GreaterEuropean,WestEuropean,French
# 42           0         2          12                  GreaterAfrican,Muslim
# ...        ...       ...         ...                                    ...
# 594          0         1           5                GreaterEuropean,British
# 595          0         1           5                  GreaterAfrican,Muslim
# 168          0         1           6                GreaterEuropean,British
# 597          0         1           7                GreaterEuropean,British
# 598          0         1           7                GreaterAfrican,Africans
# 574          0         1           4                 GreaterEuropean,Jewish
# 573          0         1           7                GreaterEuropean,British
# 172          0         1           7                GreaterEuropean,British
# 178          0         1           4                GreaterEuropean,British
# 547          0         2          11  GreaterEuropean,WestEuropean,Germanic
# 181          0         2          15           GreaterEuropean,EastEuropean
# 550          0         1           8    GreaterEuropean,WestEuropean,French
# 551          0         1           9                GreaterAfrican,Africans
# 552          0         1           4       Asian,GreaterEastAsian,EastAsian
# 553          0         2          15  GreaterEuropean,WestEuropean,Hispanic
# 180          0         1           5                GreaterEuropean,British
# 179          0         1           6                  GreaterAfrican,Muslim
# 558          0         2          11    GreaterEuropean,WestEuropean,French
# 571          0         1           6        Asian,GreaterEastAsian,Japanese
# 559          0         1           6                GreaterEuropean,British
# 560          0         1           8                GreaterAfrican,Africans
# 561          0         1           7   GreaterEuropean,WestEuropean,Italian
# 562          0         1           7    GreaterEuropean,WestEuropean,French
# 563          0         1           8   GreaterEuropean,WestEuropean,Italian
# 564          0         1          10  GreaterEuropean,WestEuropean,Germanic
# 175          0         1          11                GreaterAfrican,Africans
# 568          0         1           6    GreaterEuropean,WestEuropean,French
# 569          0         1           8   GreaterEuropean,WestEuropean,Italian
# 1            0         2          14                 GreaterEuropean,Jewish
# 1139         0         1           7  GreaterEuropean,WestEuropean,Hispanic
#
#       Asian,GreaterEastAsian,EastAsian  Asian,GreaterEastAsian,Japanese  \
# 237                           0.003992                         0.005343
# 886                           0.009047                         0.023498
# 318                           0.023244                         0.010613
# 290                           0.002814                         0.000139
# 251                           0.009281                         0.000623
# 441                           0.000669                         0.002996
# 566                           0.022633                         0.039853
# 807                           0.003848                         0.004103
# 679                           0.023244                         0.010613
# 89                            0.000026                         0.000046
# 1056                          0.039481                         0.004346
# 735                           0.017760                         0.003343
# 100                           0.000995                         0.004706
# 1110                          0.004858                         0.003886
# 414                           0.001548                         0.601116
# 155                           0.010611                         0.004630
# 745                           0.086531                         0.035844
# 1070                          0.001526                         0.001088
# 737                           0.025556                         0.008055
# 351                           0.004469                         0.006026
# 696                           0.001526                         0.001088
# 350                           0.004443                         0.009165
#
#       GreaterEuropean,WestEuropean,Nordic
# 237                          4.766296e-03
# 886                          1.214440e-03
# 318                          2.147418e-03
# 290                          4.824538e-03
# 251                          5.518856e-03
# 441                          3.668275e-02
# 566                          6.157563e-04
# 807                          1.404531e-03
# 679                          2.147418e-03
# 89                           6.150399e-06
# 1056                         2.900981e-02
# 735                          6.287064e-03
# 100                          5.142297e-02
# 1110                         1.216977e-02
# 414                          4.155552e-05
# 155                          7.645167e-03
# 745                          5.604021e-02
# 1070                         8.954696e-03
# 737                          1.001036e-02
# 351                          1.001064e-02
# 696                          8.954696e-03
# 350                          1.384053e-02
# 629                          6.157563e-04
# 458                          2.512570e-02
# 909                          2.100324e-03
# 1025                         2.183943e-03
# 557                          6.998968e-02
# 848                          4.403802e-04
# 159                          2.011408e-02
# 42                           5.833482e-02
# ...                                   ...
# 594                          3.523669e-02
# 595                          5.804281e-02
# 168                          1.104609e-02
# 597                          1.022320e-02
# 598                          9.779601e-04
# 574                          3.657548e-02
# 573                          1.149053e-01
# 172                          5.948296e-03
# 178                          1.404182e-03
# 547                          4.165369e-03
# 181                          3.490347e-02
# 550                          9.777181e-03
# 551                          5.091639e-04
# 552                          1.917597e-03
# 553                          1.294397e-03
# 180                          4.820476e-03
# 179                          2.043518e-03
# 558                          3.942126e-04
# 571                          5.584710e-04
# 559                          1.891244e-02
# 560                          2.417327e-02
# 561                          1.700946e-02
# 562                          2.260182e-03
# 563                          1.081986e-02
# 564                          5.262160e-03
# 175                          3.348947e-07
# 568                          1.624721e-04
# 569                          1.451915e-03
# 1                            7.492349e-04
# 1139                         9.203985e-03
#
# [1070 rows x 20 columns]

# %%
preds2 = preds2.groupby('surname').agg('sum').reset_index()

# %%
def returncolname(row, colnames):
    col = np.argmax(row.values[2:])
    new_pos = col + 2
                    
    return colnames[new_pos]

# %%
preds2 = preds2.drop(['no_words', 'has_nums', 'no_letters'], axis = 1)

# %%
preds2['race'] = preds2.apply(lambda x: returncolname(x, preds2.columns), axis=1)

# %%
preds2['african'] = preds2['race'].apply(lambda x: 'African' if x=='GreaterAfrican,Africans' else ('African' if x== 'GreaterAfrican,Muslim' else 'Non-African'))

# %%
#manual fixes
for name in fix_list:
    preds2.loc[preds2['surname']==name, 'african'] = 'African'
    
plt.figure(figsize=[18,4])
plt.xticks(rotation=45)
plt.title('Count of People Mentions Scraped June 2021 from Google Serach Results: Benin Bronzes')
g = sns.barplot(data=preds2.sort_values('count', ascending = False)[0:35], 
             x="surname", 
             y="count",
             hue="african")
         
ax=g
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=8, color='gray', xytext=(0, 5),
                textcoords='offset points')
_ = ax.set_ylim(0,80) #To make space for the annotations
plt.savefig('../artefacts/bb_gc_mentionsperperson.eps', format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
preds2.sort_values('count', ascending = False).reset_index().to_csv('bb_mentions.csv')

# %%
ratio = preds2.groupby('african').agg('sum').reset_index()
plt.figure(figsize=[5,6])
plt.xticks(rotation=45)
plt.title('Count of People Mentions Per Ethnicity Scraped June 2021 from Google Search Results: Benin Bronzes')
g = sns.barplot(data=ratio, 
             x="african", 
             y="count",
             hue="african") 
ax=g
for p in ax.patches:
    ax.annotate("%.0f" % p.get_height(), (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', fontsize=8, color='gray', xytext=(0, 5),
                textcoords='offset points')
_ = ax.set_ylim(0,1900) #To make space for the annotations
plt.savefig('../artefacts/bb_gc_mentionsperethnicity.eps', format='eps')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
def ner_article(text):
    """Takes in a string of text and returns persons mentioned
    
        Args:
            :param text: string, a string containing entire corpus
    """
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)

    entities = []

    for ent in doc.ents:
        if ent.label_ == 'PERSON':
            entities.append(str(ent))

    return entities

# %%
df = df[~df['text'].isna()]
df['persons'] = df['text'].apply(lambda x: ner_article(x))
# filter by single year
df['html_date'] = df['html_date'].astype('datetime64[ns]')
df_filtered = df[df['html_date'].dt.strftime('%Y') > '2015']
df_filtered['year'] = df['html_date'].dt.strftime('%Y')
# Out:
# /Users/Lono/miniconda3/envs/ethnicenv/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
year_author = df_filtered.set_index('year', append=True).persons.apply(pd.Series).stack().reset_index(level=[0, 2], drop=True).reset_index()
year_author = year_author[~year_author[0].str.contains('Benin')]
year_author['surname'] = year_author[0].apply(lambda x: clean_name(x, True))

# %%
year_author = year_author[~year_author['surname'].str.contains("\/")]
year_author = year_author[~year_author['surname'].str.contains("\(")]
year_author = year_author[~year_author['surname'].str.contains("\.")]
year_author = year_author[~year_author['surname'].str.contains("\|")]
year_author = year_author[~year_author['surname'].str.contains("\--")]
year_author = year_author[~year_author['surname'].str.contains("\- ")]
year_author = year_author[~year_author['surname'].str.contains("ii")]
year_author = year_author[~year_author['surname'].str.contains("iv")]
year_author['surname'] = year_author['surname'].str.replace("'s'", '')
year_author['has_nums'] = year_author['surname'].apply(lambda x: len(re.findall('\d+', x)))
year_author = year_author[year_author['has_nums'] ==0]
year_author['no_words'] = year_author['surname'].apply(lambda x: len(x.split()))
year_author = year_author[year_author['no_words'] <=3]
year_author['no_letters'] = year_author['surname'].apply(lambda x: len(x))
year_author = year_author[year_author['no_letters'] >1]

# %%
preds = pred_wiki_ln(year_author, "surname")
preds['african'] = preds['race'].apply(lambda x: 'African' if x=='GreaterAfrican,Africans' else ('African' if x== 'GreaterAfrican,Muslim' else 'Non-African'))
#manual fixes
for name in fix_list:
    preds.loc[preds['surname']==name, 'african'] = 'African'
preds['count'] = 1
ratio = preds.groupby(['year','african']).agg('sum').reset_index()

# %%
catp = sns.catplot(x = "year",   # x variable name
            y = "count",      # y variable name
            hue = "african",  # group variable name
            data = ratio,     # dataframe to plot
            kind = "bar")

# This will merge columns in order of the chart
vals = ratio[ratio['african'] == 'African']['count'].to_list() + ratio[ratio['african'] == 'Non-African']['count'].to_list()
    
# Add the values on top of each correct bar
i = 0
for idx, p in enumerate(catp.ax.patches):
    height = p.get_height()
    catp.ax.text(p.get_x()+p.get_width()/2.,
            height + height*.03,
            vals[idx],
            ha="center")
_ = catp.ax.set_ylim(0,1400) #To make space for the annotations
plt.xticks(rotation=45)
plt.suptitle('Ethnicity over the years: Benin Bronze', size=16, y=1.12)
plt.savefig('../artefacts/bb_gc_citesperethnicity.eps', format='eps')
plt.show()

# %% [markdown]
# TODO: need to fix this because there are some times where only the surname is mentioned, need to group by on that before getting the ethnicity to get a proper representation of the numbers
